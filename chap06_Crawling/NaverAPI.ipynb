# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

# %%
def clean_html(x):
  #https://predictor-ver1.tistory.com/4
  x = re.sub("\&\w*\;","",x)
  x = re.sub("<.*?>","",x)
  return x

# %%
client_id = "yoVPvo33INGZvy8qzgex" #발급받은 ID 입력
client_secret = "L2rPqHXi01" #발급받은 PW 입력
encText = urllib.parse.quote("EPL") # 검색할 단어 입력
url = "https://openapi.naver.com/v1/search/news?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    result = response_body.decode('utf-8')
    #print(result)
else:
    print("Error Code:" + rescode)

# %%
result_json = json.loads(result)

# %%
df_json = pd.DataFrame(result_json["items"])

# %%
df_json
# Out:
#                                                title  \
# 0  &quot;나도 두려워 리버풀이 다 우승할 것 같아서&quot;...맨유 레전드 걱...
# 1  <b>EPL</b>·세리에 A 빅클럽 '괴물' 김민재 원한다, 관건은 남은 계약기간...
# 2                      '흥행 보증 수표' 북런던 더비, 일정 윤곽 드러났다
# 3       베컴 &quot;이동 거리 짧은 카타르에서의 월드컵, 선수들에겐 축복&quot;
# 4  유로 2020 '신데렐라' <b>EPL</b> 최고 수비형 MF, 소속팀 재계약 농...
# 5  [442.exclusive] 현시점 <b>EPL</b> '16위' 파비뉴, &quo...
# 6  '공짜는 넘길 순 없어!' 아스널, 6년차 FW와 1년 연장 계획...바르사-리옹이...
# 7  [공식발표] '박지성∙손흥민 전 동료' 판니스텔로이, PSV 감독 부임...2025...
# 8  '돈 앞에 이적 못 막는다 인정' 돌문 회장, &quot;맨시티, 재정적으로 따라갈...
# 9  'SON, <b>EPL</b> 트로피 없는 역대 최고의 선수 10인'…리네커 &qu...
#
#                                         originallink  \
# 0  http://www.mydaily.co.kr/new_yk/html/read.php?...
# 1  http://sports.chosun.com/news/ntype.htm?id=202...
# 2  http://www.interfootball.co.kr/news/articleVie...
# 3             https://www.news1.kr/articles/?4633169
# 4  http://sports.chosun.com/news/ntype.htm?id=202...
# 5  http://www.fourfourtwo.co.kr/news/articleView....
# 6  http://www.fourfourtwo.co.kr/news/articleView....
# 7  http://www.footballist.co.kr/news/articleView....
# 8  http://www.interfootball.co.kr/news/articleVie...
# 9  http://www.mydaily.co.kr/new_yk/html/read.php?...
#
#                                                 link  \
# 0  https://sports.news.naver.com/news.nhn?oid=117...
# 1  https://sports.news.naver.com/news.nhn?oid=076...
# 2  https://sports.news.naver.com/news.nhn?oid=413...
# 3  https://sports.news.naver.com/news.nhn?oid=421...
# 4  https://sports.news.naver.com/news.nhn?oid=076...
# 5  https://sports.news.naver.com/news.nhn?oid=411...
# 6  https://sports.news.naver.com/news.nhn?oid=411...
# 7  https://sports.news.naver.com/news.nhn?oid=436...
# 8  https://sports.news.naver.com/news.nhn?oid=413...
# 9  https://sports.news.naver.com/news.nhn?oid=117...
#
#                                          description  \
# 0  잉글랜드 프리미어리그(<b>EPL</b>)는 끝을 향해 달려가고 있다. 5월 말에 ...
# 1  벤투호의 핵심 수비수 김민재(25)가 터키 페네르바체에 둥지를 튼 지 한 시즌 만에...
# 2  4월의 경우, 토트넘과 아스널 모두 잉글리시 프리미어리그(<b>EPL</b>) 5경...
# 3  베컴은 &quot;나는 세계에서 가장 길고 힘든 리그 중 하나인 잉글랜드 프리미어리...
# 4  <b>EPL</b> 최고의 수비형 미드필더 중 하나인 칼빈 필립스는 리즈 토박이다....
# 5  우리는 잉글리시 프리미어리그(<b>EPL</b>) 베스트 플레이어 TOP100을 작...
# 6  이번 시즌 잉글리시 프리미어리그(<b>EPL</b>)에서 단 4골을 넣은 30세의 ...
# 7  2001년 맨체스터유나이티드에 입단한 뒤 잉글랜드 프리미어리그(<b>EPL</b>)...
# 8  맨시티는 잉글리시 프리미어리그(<b>EPL</b>) 역대 최고 연봉을 준비할 예정이...
# 9  손흥민이 잉글랜드의 레전드들로부터 프리미어리그를 대표하는 선수 중 한명으로 언급됐다...
#
#                            pubDate
# 0  Thu, 31 Mar 2022 10:18:00 +0900
# 1  Thu, 31 Mar 2022 10:08:00 +0900
# 2  Thu, 31 Mar 2022 09:56:00 +0900
# 3  Thu, 31 Mar 2022 09:54:00 +0900
# 4  Thu, 31 Mar 2022 09:42:00 +0900
# 5  Thu, 31 Mar 2022 09:21:00 +0900
# 6  Thu, 31 Mar 2022 09:15:00 +0900
# 7  Thu, 31 Mar 2022 08:13:00 +0900
# 8  Thu, 31 Mar 2022 08:09:00 +0900
# 9  Thu, 31 Mar 2022 08:06:00 +0900

# %%
df_json['title'] = df_json['title'].apply(lambda x: clean_html(x))
df_json['description'] = df_json['description'].apply(lambda x: clean_html(x))

# %%
df_json
# Out:
#                                                title  \
# 0            나도 두려워 리버풀이 다 우승할 것 같아서...맨유 레전드 걱정이 태산
# 1   EPL·세리에 A 빅클럽 '괴물' 김민재 원한다, 관건은 남은 계약기간 4년 이적...
# 2                      '흥행 보증 수표' 북런던 더비, 일정 윤곽 드러났다
# 3                   베컴 이동 거리 짧은 카타르에서의 월드컵, 선수들에겐 축복
# 4  유로 2020 '신데렐라' EPL 최고 수비형 MF, 소속팀 재계약 농후. 리버풀 ...
# 5  [442.exclusive] 현시점 EPL '16위' 파비뉴, 리버풀에서 은퇴? 이...
# 6  '공짜는 넘길 순 없어!' 아스널, 6년차 FW와 1년 연장 계획...바르사-리옹이...
# 7  [공식발표] '박지성∙손흥민 전 동료' 판니스텔로이, PSV 감독 부임...2025...
# 8    '돈 앞에 이적 못 막는다 인정' 돌문 회장, 맨시티, 재정적으로 따라갈 수 없...
# 9  'SON, EPL 트로피 없는 역대 최고의 선수 10인'…리네커 훌륭하고 엄청난 선...
#
